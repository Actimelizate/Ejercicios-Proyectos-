# %%
file = 'dbfs:/FileStore/shared_uploads/edurf.cld@gmail.com/quijote-26.txt'

# %%
lineas = sc.textFile(file)

lineas.take(5)
# Out:
# Out[2]: ['Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo',
#  'don Quijote de la Mancha',
#  '',
#  '',
#  'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho']

# %%
lineas.count()
# Out:
# Out[3]: 36881

# %%
lineas.take(5)
# Out:
# Out[4]: ['Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo',
#  'don Quijote de la Mancha',
#  '',
#  '',
#  'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho']

# %%
palabras_linea  = lineas.map(lambda elemento: len(elemento))

palabras_linea.take(5)
# Out:
# Out[5]: [74, 24, 0, 0, 73]

# %%
palabras_linea.reduce(lambda e1, e2: e1 + e2)
# Out:
# Out[7]: 2034318

# %%
lineas.take(5)
# Out:
# Out[8]: ['Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo',
#  'don Quijote de la Mancha',
#  '',
#  '',
#  'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho']

# %%
palabras_linea = lineas.map(lambda elemento: elemento.split())

palabras_linea.take(5)
# Out:
# Out[9]: [['Capítulo',
#   'primero.',
#   'Que',
#   'trata',
#   'de',
#   'la',
#   'condición',
#   'y',
#   'ejercicio',
#   'del',
#   'famoso',
#   'hidalgo'],
#  ['don', 'Quijote', 'de', 'la', 'Mancha'],
#  [],
#  [],
#  ['En',
#   'un',
#   'lugar',
#   'de',
#   'la',
#   'Mancha,',
#   'de',
#   'cuyo',
#   'nombre',
#   'no',
#   'quiero',
#   'acordarme,',
#   'no',
#   'ha',
#   'mucho']]

# %%
num_palabras_linea = palabras_linea.map(lambda elemento: len(elemento))

num_palabras_linea.take(5)
# Out:
# Out[10]: [12, 5, 0, 0, 15]

# %%
num_palabras_linea.reduce(lambda e1, e2: e1 + e2)
# Out:
# Out[11]: 376500

# %%
lineas.take(5)
# Out:
# Out[12]: ['Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo',
#  'don Quijote de la Mancha',
#  '',
#  '',
#  'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho']

# %%
palabras = lineas.flatMap(lambda elemento: elemento.split())

palabras.take(15)
# Out:
# Out[15]: ['Capítulo',
#  'primero.',
#  'Que',
#  'trata',
#  'de',
#  'la',
#  'condición',
#  'y',
#  'ejercicio',
#  'del',
#  'famoso',
#  'hidalgo',
#  'don',
#  'Quijote',
#  'de']

# %%
palabras.count()
# Out:
# Out[16]: 376500
